# %%
import matplotlib.pyplot as plt

# %%
from PythonHub import PythonHub
python = PythonHub()

# %%
timeData, voltData = python.loadVoltTable()

# %%
plt.plot(timeData, voltData) # x 데이터: timeData, y 데이터: voltData

# %%
plt.plot(timeData, voltData)
plt.savefig('volt.png') # 현재 plot을 volt.png로 저장

# %%
python.statVoltTable()
# Out:
# 평균 = 3.301245443478261
# D:\Python_2024_2\PythonHub.py:125: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = psql.read_sql('SELECT * FROM volt_table', self.conn)

# %%
python.
